# %% [markdown]
# ### BAYESIAN FROM PARABOLA

# %%
# %pylab inline
#load the list of points
obs_data = loadtxt("movimiento.dat")
x_obs = obs_data[:,0]
y_obs = obs_data[:,1]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['beta', 'griddata']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
scatter(x_obs,y_obs)

# %%
def likelihood(y_obs, y_model):
    chi_squared = (1.0/2.0)*sum((y_obs-y_model)**2)
    return (-chi_squared)

# %%
def my_model(x_obs, a, b, c):
    return (a*(x_obs**2))+(b*x_obs) + c

# %%
a_walk = empty((0)) #this is an empty list to keep all the steps
b_walk = empty((0))
c_walk = empty((0))
l_walk = empty((0))

a_walk = append(a_walk, random.random())
b_walk = append(b_walk, random.random())
c_walk = append(c_walk, random.random())

y_init = my_model(x_obs, a_walk[0], b_walk[0], c_walk[0])
l_walk = append(l_walk, likelihood(y_obs, y_init))
print a_walk
print b_walk
print c_walk
print l_walk
# Out:
# [ 0.55500756]
# [ 0.39396148]
# [ 0.11076023]
# [-360370.39722187]

# %%
resta = y_obs - y_init

# %%
resta2 = resta**2

# %%
sumaresta = sum(resta2)
print sumaresta
# Out:
# 720740.794444

# %%
resta3 = (1.0/2.0)*sumaresta
print resta3
# Out:
# 360370.397222

# %%
exponencial = exp(-resta3)
print exponencial
# Out:
# 0.0

# %%
n_iterations = 20000 #this is the number of iterations I want to make
for i in range(n_iterations):
    a_prime = np.random.normal(a_walk[i], 0.1) 
    b_prime = np.random.normal(b_walk[i], 0.1)
    c_prime = np.random.normal(c_walk[i], 0.1)

    y_init = my_model(x_obs, a_walk[i], b_walk[i], c_walk[i])
    y_prime = my_model(x_obs, a_prime, b_prime, c_prime)
    
    l_prime = likelihood(y_obs, y_prime)
    l_init = likelihood(y_obs, y_init)
    
    alpha = l_prime/l_init
    if(alpha<=1.0):
        a_walk  = append(a_walk,a_prime)
        b_walk  = append(b_walk,b_prime)
        c_walk  = append(c_walk,c_prime)
        l_walk = append(l_walk, l_prime)
    else:
        beta = random.random()
        if(beta<=(exp(-alpha))):
            a_walk = append(a_walk,a_prime)
            b_walk = append(b_walk,b_prime)
            c_walk = append(c_walk,c_prime)
            l_walk = append(l_walk, l_prime)
        else:
            a_walk = append(a_walk,a_walk[i])
            b_walk = append(b_walk,b_walk[i])
            c_walk = append(c_walk,c_walk[i])
            l_walk = append(l_walk, l_init)

# %%
scatter(a_walk, b_walk)

# %%
scatter(a_walk, -(l_walk))

# %%
scatter(b_walk, -(l_walk))

# %%
scatter(c_walk, -(l_walk))

# %%
min_b = amin(b_walk)
max_b = amax(b_walk)
min_a = amin(a_walk)
max_a = amax(a_walk)
min_c = amin(c_walk)
max_c = amax(c_walk)
grid_a, grid_b = mgrid[min_a:max_a:200j, min_b:max_b:200j]

# %%
from scipy.interpolate import griddata
n_points = size(a_walk)
points = ones((n_points,2))
print shape(points)
points[:,0] = a_walk
points[:,1] = b_walk
grid_l = griddata(points, -(l_walk), (grid_a, grid_b), method='cubic')
imshow(grid_l.T, extent=(min_a,max_a,min_b,max_b), aspect='auto',origin='lower')
# Out:
# (20001, 2)

# %%
grid_b, grid_c = mgrid[min_b:max_b:200j, min_c:max_c:200j]

# %%
from scipy.interpolate import griddata
n_points = size(b_walk)
points = ones((n_points,2))
print shape(points)
points[:,0] = b_walk
points[:,1] = c_walk
grid_l = griddata(points, -(l_walk), (grid_b, grid_c), method='cubic')
imshow(grid_l.T, extent=(min_b,max_b,min_c,max_c), aspect='auto',origin='lower')
# Out:
# (20001, 2)

# %%
grid_a, grid_c = mgrid[min_a:max_a:200j, min_c:max_c:200j]

# %%
from scipy.interpolate import griddata
n_points = size(a_walk)
points = ones((n_points,2))
print shape(points)
points[:,0] = a_walk
points[:,1] = c_walk
grid_l = griddata(points, -(l_walk), (grid_a, grid_c), method='cubic')
imshow(grid_l.T, extent=(min_a,max_a,min_c,max_c), aspect='auto',origin='lower')
# Out:
# (20001, 2)

# %%
count, bins, ignored =plt.hist(a_walk, 20, normed=True)

# %%
count, bins, ignored =plt.hist(b_walk, 20, normed=True)

# %%
count, bins, ignored =plt.hist(c_walk, 20, normed=True)

# %%
max_likelihood_id = argmax(l_walk)
best_a = a_walk[max_likelihood_id]
best_b = b_walk[max_likelihood_id]
best_c = c_walk[max_likelihood_id]
print (l_walk[max_likelihood_id])
print best_a
print best_b
print best_c
# Out:
# -913.560607541
# -4.95234443486
# 50.5761914331
# 6.25945396842

# %%
best_y = my_model(x_obs, best_a, best_b, best_c)
scatter(x_obs,y_obs, c='r')
plot(x_obs, best_y, c='b')
title("BAYESIAN OF PARABOLA")
